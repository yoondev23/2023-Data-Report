# %% [markdown]
# ! pip install osmnx
# ! pip install networkx
# ! pip install folium

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import osmnx as ox
import networkx as nx
import folium

# %%
#맵 호출
G1 = ox.graph_from_place('부산광역시, 대한민국', network_type='drive', simplify=False)

#노드에 좌표 입력
orig_node1 = ox.nearest_nodes(G1,129.120512329434, 35.16849674828806)
dest_node1 = ox.nearest_nodes(G1,129.12663966074993, 35.177905402602974)

orig_node2 = ox.nearest_nodes(G1,129.12663966074993, 35.177905402602974)
dest_node2 = ox.nearest_nodes(G1,129.08575064101666, 35.22021388194493)

orig_node3 = ox.nearest_nodes(G1,129.08575064101666, 35.22021388194493)
dest_node3 = ox.nearest_nodes(G1,129.00323111099627, 35.21555221991222)

orig_node4 = ox.nearest_nodes(G1,129.00323111099627, 35.21555221991222)
dest_node4 = ox.nearest_nodes(G1,128.9176367226655,  35.098342342342576)

orig_node5 = ox.nearest_nodes(G1,129.00323111099627, 35.21555221991222)
dest_node5 = ox.nearest_nodes(G1,128.9176367226655,  35.098342342342576)

orig_node6 = ox.nearest_nodes(G1,128.9176367226655,  35.098342342342576)
dest_node6 = ox.nearest_nodes(G1,128.93972060453487, 35.093701244026626)

orig_node7 = ox.nearest_nodes(G1,128.93972060453487, 35.093701244026626)
dest_node7 = ox.nearest_nodes(G1,128.97792971638148, 35.09585940015882)

orig_node8 = ox.nearest_nodes(G1,128.97792971638148, 35.09585940015882)
dest_node8 = ox.nearest_nodes(G1,128.97320999214693, 35.102028348884026)


#경로
route1 =  nx.shortest_path(G1, orig_node1, dest_node1, weight='length')
route2 =  nx.shortest_path(G1, orig_node2, dest_node2, weight='length')
route3 =  nx.shortest_path(G1, orig_node3, dest_node3, weight='length')
route4 =  nx.shortest_path(G1, orig_node4, dest_node4, weight='length')
route5 =  nx.shortest_path(G1, orig_node5, dest_node5, weight='length')
route6 =  nx.shortest_path(G1, orig_node6, dest_node6, weight='length')
route7 =  nx.shortest_path(G1, orig_node7, dest_node7, weight='length')
route8 =  nx.shortest_path(G1, orig_node8, dest_node8, weight='length')
route_list = [route1,route2,route3,route4,route5,route6,route7,route8]

#첫 번째 경로
R1 = ox.folium.plot_route_folium(G1, route1, route_map=None,   #초기 route_map은 None으로 설정해주어야함
                                 tiles='Stamen Terrain', #베이스맵
                                 color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1) #라인 투명도

#두 번째 경로
R2 = ox.folium.plot_route_folium(G1, route2, route_map=R1,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#세 번째 경로
R3 = ox.folium.plot_route_folium(G1, route3, route_map=R1,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#네 번째 경로
R4 = ox.folium.plot_route_folium(G1, route4, route_map=R3,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

# 다섯 번째 경로
R5 = ox.folium.plot_route_folium(G1, route5, route_map=R4,
                                  tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#여섯 번째 경로
R6 = ox.folium.plot_route_folium(G1, route6, route_map=R5,
                                  tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#일곱 번째 경로
R7 = ox.folium.plot_route_folium(G1, route7, route_map=R6,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#여덟 번째 경로
R8 = ox.folium.plot_route_folium(G1, route8, route_map=R7,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#맵 출력
R8

marker1 = folium.Marker( [ 35.16849674828806 , 129.120512329434 ], icon = folium.Icon(color='blue'))
marker2 = folium.Marker( [ 35.177905402602974 , 129.12663966074993 ], icon = folium.Icon(color='blue'))
marker3 = folium.Marker( [ 35.22021388194493 , 129.08575064101666 ], icon = folium.Icon(color='blue'))
marker4 = folium.Marker( [ 35.098342342342576 , 128.9176367226655 ], icon = folium.Icon(color='blue'))
marker5 = folium.Marker( [ 35.09585940015882 , 128.97792971638148 ], icon = folium.Icon(color='blue'))
marker6 = folium.Marker( [ 35.102028348884026 , 128.97320999214693 ], icon = folium.Icon(color='blue'))
marker1.add_to( R5 )
marker2.add_to( R5 )
marker3.add_to( R5 )
marker4.add_to( R5 )
marker5.add_to( R5 )
marker6.add_to( R5 )

R8
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from numpy import rot90
#맵 호출
G1 = ox.graph_from_place('부산광역시, 대한민국', network_type='drive', simplify=False)

#노드에 좌표 입력
orig_node1 = ox.nearest_nodes(G1,129.12024485502727, 35.16833922529888)
dest_node1 = ox.nearest_nodes(G1,129.125358583877, 35.16579845173455)

orig_node2 = ox.nearest_nodes(G1,129.125358583877, 35.16579845173455)
dest_node2 = ox.nearest_nodes(G1,129.11392435809563, 35.193790033183646)

orig_node3 = ox.nearest_nodes(G1,129.11392435809563, 35.193790033183646)
dest_node3 = ox.nearest_nodes(G1,129.00323111099627, 35.21555221991222)

orig_node4 = ox.nearest_nodes(G1,129.00323111099627, 35.21555221991222)
dest_node4 = ox.nearest_nodes(G1,129.0025063998158,  35.216447355714784)

orig_node5 = ox.nearest_nodes(G1,129.0025063998158,  35.216447355714784)
dest_node5 = ox.nearest_nodes(G1,128.96202428255216,  35.114808546432236)

orig_node6 = ox.nearest_nodes(G1,128.96202428255216,  35.114808546432236)
dest_node6 = ox.nearest_nodes(G1,128.9686641740303, 35.106337851990055)

orig_node7 = ox.nearest_nodes(G1,128.9686641740303, 35.106337851990055)
dest_node7 = ox.nearest_nodes(G1,128.93201927365152, 35.11118122760246)

orig_node8 = ox.nearest_nodes(G1,128.93201927365152, 35.11118122760246)
dest_node8 = ox.nearest_nodes(G1,128.89641310218926, 35.08910552867441)

orig_node9 = ox.nearest_nodes(G1,128.89641310218926, 35.08910552867441)
dest_node9 = ox.nearest_nodes(G1,128.8870069047967, 35.09549080820638)

orig_node10 = ox.nearest_nodes(G1,128.8870069047967, 35.09549080820638)
dest_node10 = ox.nearest_nodes(G1,128.8689875537351, 35.101896030563935)

#경로
route1 =  nx.shortest_path(G1, orig_node1, dest_node1, weight='length')
route2 =  nx.shortest_path(G1, orig_node2, dest_node2, weight='length')
route3 =  nx.shortest_path(G1, orig_node3, dest_node3, weight='length')
route4 =  nx.shortest_path(G1, orig_node4, dest_node4, weight='length')
route5 =  nx.shortest_path(G1, orig_node5, dest_node5, weight='length')
route6 =  nx.shortest_path(G1, orig_node6, dest_node6, weight='length')
route7 =  nx.shortest_path(G1, orig_node7, dest_node7, weight='length')
route8 =  nx.shortest_path(G1, orig_node8, dest_node8, weight='length')
route9 =  nx.shortest_path(G1, orig_node9, dest_node9, weight='length')
route10 =  nx.shortest_path(G1, orig_node10, dest_node10, weight='length')
route_list = [route1,route2,route3,route4,route5,route6,route7,route8,route9,route10]

#첫 번째 경로
R1 = ox.folium.plot_route_folium(G1, route1, route_map=None,   #초기 route_map은 None으로 설정해주어야함
                                 tiles='Stamen Terrain', #베이스맵
                                 color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1) #라인 투명도

#두 번째 경로
R2 = ox.folium.plot_route_folium(G1, route2, route_map=R1,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#세 번째 경로
R3 = ox.folium.plot_route_folium(G1, route3, route_map=R1,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#네 번째 경로
R4 = ox.folium.plot_route_folium(G1, route4, route_map=R3,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

# 다섯 번째 경로
R5 = ox.folium.plot_route_folium(G1, route5, route_map=R4,
                                  tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#여섯 번째 경로
R6 = ox.folium.plot_route_folium(G1, route6, route_map=R5,
                                  tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#일곱 번째 경로
R7 = ox.folium.plot_route_folium(G1, route7, route_map=R6,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#여덟 번째 경로
R8 = ox.folium.plot_route_folium(G1, route8, route_map=R7,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#아홉 번째 경로
R9 = ox.folium.plot_route_folium(G1, route9, route_map=R8,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#열 번째 경로
R10 = ox.folium.plot_route_folium(G1, route10, route_map=R9,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#맵 출력
R10

marker1 = folium.Marker( [ 35.09549080820638 , 128.8868678967813], icon = folium.Icon(color='blue'))
marker2 = folium.Marker( [ 35.10624374598132  , 128.96835485336589 ], icon = folium.Icon(color='blue'))
marker3 = folium.Marker( [ 35.204461915372576  ,  129.07840873192734 ], icon = folium.Icon(color='blue'))
marker4 = folium.Marker( [ 35.1686879946372 , 129.12091237301206 ], icon = folium.Icon(color='blue'))
marker1.add_to( R10 )
marker2.add_to( R10 )
marker3.add_to( R10 )
marker4.add_to( R10 )


R10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#맵 호출
G1 = ox.graph_from_place('부산광역시, 대한민국', network_type='drive', simplify=False)

#노드에 좌표 입력
orig_node1 = ox.nearest_nodes(G1,129.08695476351758, 35.239784070036244)
dest_node1 = ox.nearest_nodes(G1,129.00743714983952, 35.23651567398956)

orig_node2 = ox.nearest_nodes(G1,129.00743714983952, 35.23651567398956)
dest_node2 = ox.nearest_nodes(G1,128.97581247953192, 35.16436571054985)

orig_node3 = ox.nearest_nodes(G1,128.97581247953192, 35.16436571054985)
dest_node3 = ox.nearest_nodes(G1,128.92694888025753, 35.12778981912814)


#경로
route1 =  nx.shortest_path(G1, orig_node1, dest_node1, weight='length')
route2 =  nx.shortest_path(G1, orig_node2, dest_node2, weight='length')
route3 =  nx.shortest_path(G1, orig_node3, dest_node3, weight='length')
route_list = [route1,route2,route3]

#첫 번째 경로
R1 = ox.folium.plot_route_folium(G1, route1, route_map=None,   #초기 route_map은 None으로 설정해주어야함
                                 tiles='Stamen Terrain', #베이스맵
                                 color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1) #라인 투명도

#두 번째 경로
R2 = ox.folium.plot_route_folium(G1, route2, route_map=R1,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#세 번째 경로
R3 = ox.folium.plot_route_folium(G1, route3, route_map=R1,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#맵 출력
R3


marker1 = folium.Marker( [ 35.12778981912814 , 128.92694888025753], icon = folium.Icon(color='blue'))
marker2 = folium.Marker( [ 35.15446269233309  ,128.97630811279151 ], icon = folium.Icon(color='blue'))
marker3 = folium.Marker( [ 35.239784070036244  , 129.08695476351758 ], icon = folium.Icon(color='blue'))
marker1.add_to( R3 )
marker2.add_to( R3 )
marker3.add_to( R3 )

R3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#맵 호출
G1 = ox.graph_from_place('부산광역시, 대한민국', network_type='drive', simplify=False)

#노드에 좌표 입력
orig_node1 = ox.nearest_nodes(G1,129.08695476351758, 35.239784070036244)
dest_node1 = ox.nearest_nodes(G1,129.00743714983952, 35.23651567398956)

orig_node2 = ox.nearest_nodes(G1,129.00743714983952, 35.23651567398956)
dest_node2 = ox.nearest_nodes(G1,128.97581247953192, 35.16436571054985)

orig_node3 = ox.nearest_nodes(G1,128.97581247953192, 35.16436571054985)
dest_node3 = ox.nearest_nodes(G1,128.92694888025753, 35.12778981912814)


#경로
route1 =  nx.shortest_path(G1, orig_node1, dest_node1, weight='length')
route2 =  nx.shortest_path(G1, orig_node2, dest_node2, weight='length')
route3 =  nx.shortest_path(G1, orig_node3, dest_node3, weight='length')
route_list = [route1,route2,route3]

#첫 번째 경로
R1 = ox.folium.plot_route_folium(G1, route1, route_map=None,   #초기 route_map은 None으로 설정해주어야함
                                 tiles='OpenStreetMap', #베이스맵
                                 color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1) #라인 투명도

#두 번째 경로
R2 = ox.folium.plot_route_folium(G1, route2, route_map=R1,
                                 tiles='OpenStreetMap', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#세 번째 경로
R3 = ox.folium.plot_route_folium(G1, route3, route_map=R1,
                                 tiles='OpenStreetMap', #베이스맵
                                  color='#7401DF', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도



#맵 출력
R3


marker1 = folium.Marker( [ 35.12778981912814 , 128.92694888025753], icon = folium.Icon(color='blue'))
marker2 = folium.Marker( [ 35.15446269233309  ,128.97630811279151 ], icon = folium.Icon(color='blue'))
marker3 = folium.Marker( [ 35.239784070036244  , 129.08695476351758 ], icon = folium.Icon(color='blue'))
marker1.add_to( R3 )
marker2.add_to( R3 )
marker3.add_to( R3 )

R3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#맵 호출
G1 = ox.graph_from_place('부산광역시, 대한민국', network_type='drive', simplify=False)

#노드에 좌표 입력
orig_node1 = ox.nearest_nodes(G1,129.26168692125003, 35.375647786814696)
dest_node1 = ox.nearest_nodes(G1,129.22096320163732, 35.25125735468091)

orig_node2 = ox.nearest_nodes(G1,129.22096320163732, 35.25125735468091)
dest_node2 = ox.nearest_nodes(G1,129.21335033556983, 35.249234211273794)

orig_node3 = ox.nearest_nodes(G1,129.21335033556983, 35.249234211273794)
dest_node3 = ox.nearest_nodes(G1,129.2155877469932, 35.23780309000432)

orig_node4 = ox.nearest_nodes(G1,129.2098549243622, 35.32434305533169)
dest_node4 = ox.nearest_nodes(G1,129.24621888488804, 35.312931467737826)

#경로
route1 =  nx.shortest_path(G1, orig_node1, dest_node1, weight='length')
route2 =  nx.shortest_path(G1, orig_node2, dest_node2, weight='length')
route3 =  nx.shortest_path(G1, orig_node3, dest_node3, weight='length')
route4 =  nx.shortest_path(G1, orig_node4, dest_node4, weight='length')
route_list = [route1,route2,route3,route4]

#첫 번째 경로
R1 = ox.folium.plot_route_folium(G1, route1, route_map=None,   #초기 route_map은 None으로 설정해주어야함
                                 tiles='Stamen Terrain', #베이스맵
                                 color='#FF7F27', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1) #라인 투명도

#두 번째 경로
R2 = ox.folium.plot_route_folium(G1, route2, route_map=R1,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#FF7F27', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#세 번째 경로
R3 = ox.folium.plot_route_folium(G1, route3, route_map=R1,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#FF7F27', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#네 번째 경로
R4 = ox.folium.plot_route_folium(G1, route4, route_map=R3,
                                 tiles='Stamen Terrain', #베이스맵
                                  color='#FF7F27', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#맵 출력
R4


marker1 = folium.Marker( [ 35.375647786814696 , 129.26168692125003], icon = folium.Icon(color='blue'))
marker2 = folium.Marker( [ 35.23780309000432  ,129.2155877469932 ], icon = folium.Icon(color='blue'))
marker3 = folium.Marker( [ 35.32434305533169, 129.2098549243622 ], icon = folium.Icon(color='blue'))
marker4 = folium.Marker( [ 35.312931467737826, 129.24621888488804 ], icon = folium.Icon(color='blue'))
marker1.add_to( R4 )
marker2.add_to( R4 )
marker3.add_to( R4 )
marker4.add_to( R4 )

R4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#맵 호출
G1 = ox.graph_from_place('부산광역시, 대한민국', network_type='drive', simplify=False)

#노드에 좌표 입력
orig_node1 = ox.nearest_nodes(G1,129.26168692125003, 35.375647786814696)
dest_node1 = ox.nearest_nodes(G1,129.22096320163732, 35.25125735468091)

orig_node2 = ox.nearest_nodes(G1,129.22096320163732, 35.25125735468091)
dest_node2 = ox.nearest_nodes(G1,129.21335033556983, 35.249234211273794)

orig_node3 = ox.nearest_nodes(G1,129.21335033556983, 35.249234211273794)
dest_node3 = ox.nearest_nodes(G1,129.2155877469932, 35.23780309000432)

orig_node4 = ox.nearest_nodes(G1,129.2098549243622, 35.32434305533169)
dest_node4 = ox.nearest_nodes(G1,129.24621888488804, 35.312931467737826)

#경로
route1 =  nx.shortest_path(G1, orig_node1, dest_node1, weight='length')
route2 =  nx.shortest_path(G1, orig_node2, dest_node2, weight='length')
route3 =  nx.shortest_path(G1, orig_node3, dest_node3, weight='length')
route4 =  nx.shortest_path(G1, orig_node4, dest_node4, weight='length')
route_list = [route1,route2,route3,route4]

#첫 번째 경로
R1 = ox.folium.plot_route_folium(G1, route1, route_map=None,   #초기 route_map은 None으로 설정해주어야함
                                 tiles='OpenStreetMap', #베이스맵
                                 color='#FF7F27', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1) #라인 투명도

#두 번째 경로
R2 = ox.folium.plot_route_folium(G1, route2, route_map=R1,
                                 tiles='OpenStreetMap', #베이스맵
                                  color='#FF7F27', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#세 번째 경로
R3 = ox.folium.plot_route_folium(G1, route3, route_map=R1,
                                 tiles='OpenStreetMap', #베이스맵
                                  color='#FF7F27', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도


#네 번째 경로
R4 = ox.folium.plot_route_folium(G1, route4, route_map=R3,
                                 tiles='OpenStreetMap', #베이스맵
                                  color='#FF7F27', #엣지 색깔
                                 weight=10, #엣지 굵기
                                 opacity=1)#라인 투명도

#맵 출력
R4


marker1 = folium.Marker( [ 35.375647786814696 , 129.26168692125003], icon = folium.Icon(color='blue'))
marker2 = folium.Marker( [ 35.23780309000432  ,129.2155877469932 ], icon = folium.Icon(color='blue'))
marker3 = folium.Marker( [ 35.32434305533169, 129.2098549243622 ], icon = folium.Icon(color='blue'))
marker4 = folium.Marker( [ 35.312931467737826, 129.24621888488804 ], icon = folium.Icon(color='blue'))
marker1.add_to( R4 )
marker2.add_to( R4 )
marker3.add_to( R4 )
marker4.add_to( R4 )

R4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
